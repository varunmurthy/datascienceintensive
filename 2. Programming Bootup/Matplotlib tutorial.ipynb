# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

from pylab import *

# %%
x = np.linspace(0,5,10)
y = x ** 2
y
# Out:
# array([  0.        ,   0.30864198,   1.2345679 ,   2.77777778,
#          4.9382716 ,   7.71604938,  11.11111111,  15.12345679,
#         19.75308642,  25.        ])

# %%
figure()
plot(x,y,'r')
xlabel('x')
ylabel('y')
title('Testing Matplotlib')
show()

# %%
plot?

# %%
subplot(1,2,1)
plot(x,y,'r--')
subplot(1,2,2)
plot(y,x,'g*-')
subplot(1,2,2)

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel
# Out:
# <bound method Axes.set_ylabel of <matplotlib.axes._axes.Axes object at 0x107abc510>>

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.0,0.0,1,1])
axes2 = fig.add_axes([0.1,0.6,0.4,0.3])

axes1.plot(x,y,'r')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('title')

axes2.plot(y,x,'g')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes1.set_title('insert title')

# %%
fig.add_axes?
